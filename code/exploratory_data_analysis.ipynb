# %% [markdown]
# ## Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
class CTData:

    def __init__(self, name:str, dir:str):
        data_label = pd.read_csv(dir)
        aggregated_data = []
        aggregated_data_header = []

        for i in range(84):
            if i==0:
                start = 1
            else:
                start = (i*52) + 1
            end = start + 52
            current_header = data_label.columns[start].split('*')[0]
            aggregated_data.append(data_label.iloc[:,start:end].sum(axis=1))
            aggregated_data_header.append(current_header)

        label_count = [np.count_nonzero(data > 0) for data in aggregated_data]
        data_summary = pd.DataFrame(data=[label_count], columns=aggregated_data_header)

        self.columns = aggregated_data_header
        self.raw_data = np.asarray(data_label)
        self.aggregated_data = np.asarray(aggregated_data)
        self.label_count = label_count
        self.dir = dir
        self.name = name
        self.summary = data_summary
        self.total_columns = 84

# %%
train_data = CTData("train","Source/dataset/imgtrain_Abnormality_and_Location_Labels.csv")
test_data = CTData("test","Source/dataset/imgtest_Abnormality_and_Location_Labels.csv")
val_data = CTData("val","Source/dataset/imgvalid_Abnormality_and_Location_Labels.csv")

# %%
df = pd.DataFrame([{'train':train_data.label_count, 
                        'test':test_data.label_count,
                        'valid':val_data.label_count}])

# %%
df = df.apply(pd.Series.explode)
df = df.reset_index(drop=True)

# %%
df.columns = train_data.columns

# %%
excel_file_path = 'data_label_comparison.xlsx'
df.to_excel(excel_file_path)

# %%
path = 'Source/dataset'
dir_list = os.listdir(path)

# %%
print(dir_list)
# Out:
# ['A systematic literature review of machine learning application in COVID-19 medical image classification.pdf', 'CT_Scan_Metadata_Complete_35747.csv', 'Extrema_35747.csv', 'imgtest_Abnormality_and_Location_Labels.csv', 'imgtrain_Abnormality_and_Location_Labels.csv', 'imgvalid_Abnormality_and_Location_Labels.csv', 'Indications_35747.csv', 'Summary_3630.csv', 'trn00022.npz', 'trn00039.npz', 'trn00042.npz', 'trn00058.npz', 'trn00067.npz', 'trn00093.npz', 'trn00131.npz', 'trn00139.npz', 'trn00141.npz', 'trn00143.npz', 'trn00149.npz', 'trn00167.npz', 'trn00180.npz', 'trn00187.npz', 'trn00193.npz', 'trn00195.npz', 'trn00252.npz', 'trn00268.npz', 'trn00270.npz', 'trn00277.npz', 'trn00301.npz', 'trn00309.npz', 'trn00317.npz', 'trn00318.npz', 'trn00323.npz', 'trn00324.npz', 'trn00335.npz', 'trn00336.npz', 'trn00345.npz', 'trn00347.npz', 'trn00367.npz', 'trn00370.npz', 'trn00384.npz', 'trn00393.npz', 'trn00396.npz', 'trn00420.npz', 'trn00425.npz', 'trn00428.npz', 'trn00437.npz', 'trn00450.npz', 'trn00460.npz', 'trn00468.npz', 'trn00485.npz', 'trn00506.npz', 'trn00507.npz', 'trn00518.npz', 'trn00520.npz', 'trn00525.npz', 'trn00540.npz', 'trn00544.npz', 'trn00550.npz', 'trn00552.npz', 'trn00556.npz', 'trn00565.npz', 'trn00593.npz', 'trn00601.npz', 'trn00625.npz', 'trn00636.npz', 'trn00637.npz', 'trn00646.npz', 'trn00653.npz', 'trn00655.npz', 'trn00673.npz', 'trn00685.npz', 'trn00687.npz', 'trn00695.npz', 'trn00708.npz', 'trn00717.npz', 'trn00732.npz', 'trn00758.npz', 'trn00783.npz', 'trn00785.npz', 'trn00798.npz', 'trn00802.npz', 'trn00806.npz', 'trn00817.npz', 'trn00824.npz', 'trn00842.npz', 'trn00857.npz', 'trn00859.npz', 'trn00866.npz', 'trn00869.npz', 'trn00870.npz', 'trn00878.npz', 'trn00907.npz', 'trn00915.npz', 'trn00918.npz', 'trn00925.npz', 'trn00932.npz', 'trn00936.npz', 'trn00982.npz', 'trn00994.npz', 'trn01000.npz', 'trn01011.npz', 'trn01021.npz', 'trn01039.npz', 'trn01067.npz', 'trn01072.npz', 'trn01092.npz', 'trn01113.npz', 'trn01142.npz', 'trn01165.npz', 'trn01181.npz', 'trn01194.npz', 'trn01221.npz', 'trn01226.npz', 'trn01227.npz', 'trn01254.npz', 'trn01264.npz', 'trn01269.npz', 'trn01271.npz', 'trn01292.npz', 'trn01296.npz', 'trn01325.npz', 'trn01331.npz', 'trn01340.npz', 'trn01374.npz', 'trn01402.npz', 'trn01405.npz', 'trn01420.npz', 'trn01426.npz', 'trn01451.npz', 'trn01453.npz', 'trn01472.npz', 'trn01504.npz', 'trn01511.npz', 'trn01512.npz', 'trn01513.npz', 'trn01538.npz', 'trn01556.npz', 'trn01568.npz', 'trn01571.npz', 'trn01572.npz', 'trn01574.npz', 'trn01576.npz', 'trn01580.npz', 'trn01586.npz', 'trn01596.npz', 'trn01611.npz', 'trn01621.npz', 'trn01661.npz', 'trn01671.npz', 'trn01680.npz', 'trn01683.npz', 'trn01688.npz', 'trn01691.npz', 'trn01692.npz', 'trn01694.npz', 'trn01711.npz', 'trn01714.npz', 'trn01720.npz', 'trn01732.npz', 'trn01740.npz', 'trn01766.npz', 'trn01777.npz', 'trn01783.npz', 'trn01817.npz', 'trn01824.npz', 'trn01841.npz', 'trn01848.npz', 'trn01855.npz', 'trn01856.npz', 'trn01863.npz', 'trn01886.npz', 'trn01901.npz', 'trn01910.npz', 'trn01913.npz', 'trn01918.npz', 'trn01920.npz', 'trn01921.npz', 'trn01928.npz', 'trn01940.npz', 'trn01969.npz', 'trn01976.npz', 'trn01980.npz', 'trn01991.npz', 'trn02010.npz', 'trn02025.npz', 'trn02031.npz', 'trn02040.npz', 'trn02045.npz', 'trn02047.npz', 'trn02060.npz', 'trn02068.npz', 'trn02078.npz', 'trn02094.npz', 'trn02098.npz', 'trn02100.npz', 'trn02109.npz', 'trn02122.npz', 'trn02140.npz', 'trn02150.npz', 'trn02152.npz', 'trn02157.npz', 'trn02181.npz', 'trn02187.npz', 'trn02197.npz', 'trn02245.npz', 'trn02252.npz', 'trn02255.npz', 'trn02261.npz', 'trn02271.npz', 'trn02281.npz', 'trn02300.npz', 'trn02302.npz', 'trn02314.npz', 'trn02318.npz', 'trn02341.npz', 'trn02344.npz', 'trn02347.npz', 'trn02354.npz', 'trn02365.npz', 'trn02381.npz', 'trn02382.npz', 'trn02404.npz', 'trn02410.npz', 'trn02415.npz', 'trn02419.npz', 'trn02433.npz', 'trn02443.npz', 'trn02444.npz', 'trn02452.npz', 'trn02487.npz', 'trn02490.npz', 'trn02497.npz', 'trn02502.npz', 'trn02511.npz', 'trn0255 ...

# %%
train_count = 0 
test_count = 0
valid_count = 0
for file in dir_list:
    if file.startswith('trn'):
        train_count+=1
    if file.startswith('tst'):
        test_count+=1
    if file.startswith('val'):
        valid_count+=1

# %%
print(train_count, test_count, valid_count)
# Out:
# 2286 360 984

# %%
2286+360+984
# Out:
# 3630
